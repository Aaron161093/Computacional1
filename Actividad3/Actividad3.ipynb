# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv('wyoming.txt' , skiprows=2, sep='\s+')

# %%
df0
# Out:
#       PRES   HGHT  TEMP  DWPT  RELH  MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0    915.0    874  29.2   3.2    19  5.29   300    15  310.1  326.9  311.1
# 1    905.0    970  26.2   1.2    20  4.63   304    16  308.0  322.7  308.9
# 2    900.0   1019  25.6   0.6    19  4.46   306    17  307.9  322.0  308.7
# 3    879.3   1219  23.7  -0.1    21  4.35   315    20  308.0  321.8  308.8
# 4    850.0   1512  21.0  -1.0    23  4.20   315    21  308.1  321.5  308.9
# 5    819.1   1829  18.1  -2.5    24  3.89   315    18  308.3  320.7  309.0
# 6    806.0   1968  16.8  -3.2    25  3.76   322    18  308.4  320.4  309.1
# 7    790.2   2134  15.4  -6.0    22  3.10   330    18  308.7  318.7  309.2
# 8    762.3   2438  12.9 -11.2    17  2.14   325    21  309.2  316.2  309.6
# 9    754.0   2530  12.2 -12.8    16  1.90   322    22  309.3  315.7  309.7
# 10   745.0   2631  12.6 -24.4     6  0.72   319    23  310.8  313.4  311.0
# 11   735.1   2743  12.8 -19.8     9  1.09   315    24  312.2  316.0  312.4
# 12   723.0   2882  13.0 -14.0    14  1.80   307    22  313.9  320.1  314.3
# 13   700.0   3152  11.2 -15.8    13  1.60   290    18  314.9  320.4  315.2
# 14   673.0   3478   8.8 -17.2    14  1.48   296    24  315.7  320.9  316.0
# 15   658.4   3658   7.7 -16.9    16  1.56   300    27  316.5  321.9  316.8
# 16   611.2   4267   3.9 -15.8    22  1.84   280    30  318.9  325.3  319.3
# 17   605.0   4350   3.4 -15.6    23  1.89   280    31  319.2  325.8  319.6
# 18   588.4   4572   2.1 -17.8    21  1.62   280    32  320.3  326.0  320.6
# 19   566.3   4877   0.4 -20.8    19  1.30   260    31  321.8  326.4  322.1
# 20   524.7   5486  -3.1 -26.8    14  0.82   285    29  324.7  327.8  324.9
# 21   504.0   5807  -4.9 -29.9    12  0.64   285    30  326.3  328.7  326.4
# 22   500.0   5870  -5.5 -30.5    12  0.61   285    30  326.3  328.6  326.4
# 23   485.5   6096  -7.3 -31.6    12  0.56   285    29  326.8  329.0  326.9
# 24   414.1   7315 -17.0 -37.8    15  0.36   290    28  329.5  331.0  329.6
# 25   400.0   7580 -19.1 -39.1    15  0.32   285    26  330.1  331.4  330.1
# 26   397.8   7620 -19.4 -39.4    15  0.32   285    26  330.2  331.4  330.2
# 27   372.0   8114 -23.5 -43.5    14  0.22   274    25  331.2  332.1  331.2
# 28   321.8   9144 -32.4 -46.5    23  0.18   250    24  332.9  333.6  332.9
# 29   306.0   9503 -35.5 -47.5    28  0.17   264    23  333.3  334.0  333.4
# ..     ...    ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 101   29.1  24384 -55.0 -87.2     1  0.01    90    18  599.6  599.7  599.6
# 102   28.8  24441 -55.1 -87.1     1  0.01    92    17  600.8  600.9  600.8
# 103   27.7  24689 -52.2 -85.1     1  0.01   100    14  615.5  615.6  615.5
# 104   27.6  24715 -51.9 -84.9     1  0.01    97    14  617.1  617.2  617.1
# 105   26.4  24994 -51.6 -85.0     1  0.01    65    13  625.4  625.5  625.4
# 106   25.2  25298 -51.4 -85.0     1  0.01    55    14  634.6  634.7  634.6
# 107   24.1  25603 -51.1 -85.1     1  0.01    85    13  643.9  644.0  643.9
# 108   24.0  25623 -51.1 -85.1     1  0.01    84    13  644.5  644.7  644.5
# 109   23.0  25908 -49.8 -83.8     1  0.02    70    13  656.5  656.7  656.5
# 110   21.9  26222 -48.3 -82.3     1  0.02    94    16  670.0  670.2  670.0
# 111   21.9  26213 -48.3 -82.3     1  0.02    95    16  669.6  669.8  669.6
# 112   20.9  26518 -48.4 -82.4     1  0.02    70    13  678.3  678.5  678.3
# 113   20.0  26820 -48.5 -82.5     1  0.02    80    20  687.0  687.2  687.0
# 114   19.1  27127 -48.6 -82.6     1  0.02    95    18  695.8  696.0  695.8
# 115   18.2  27432 -48.8 -82.8     1  0.02    70    18  704.6  704.9  704.7
# 116   17.4  27737 -48.9 -82.9     1  0.02    95    23  713.6  713.9  713.6
# 117   17.3  27774 -48.9 -82.9     1  0.02    95    22  714.7  715.0  714.8
# 118   15.9  28346 -45.9 -80.7     1  0.04    90     5  742.3  742.7  742.3
# 119   15.4  28546 -44.9 -79.9     1  0.04    67     9  752.1  752.6  752.1
# 120   15.2  28651 -44.9 -80.0     1  0.04    55    11  755.6  756.1  755.6
# 121   13.8  29261 -44.6 -80.4     1  0.05   100    13  776.6  777.1  776.6
# 122   13.6  29378 -44.5 -80.5     1  0.05    85    14  780.6  781.2  780.6
# 123   13.2  29566 -43.8 -79.8     1  0.05    60    15  789.4  790.0  789.5
# 124   12.7  29839 -42.7 -78.7     1  0.06    78    18  802.3  803.1  802.4
# 125   12.3  30054 -43.5 -79.5     1  0.06    92    21  806.9  807.6  806.9
# 126   12.1  30175 -42.6 -78.8     1  0.07   100    22  814.3  815.1  814.3
# 127   11.6  30480 -40.2 -77.0     1  0.09    85    11  833.3  834.4  833.3
# 128   11.4  30570 -39.5 -76.5     1  0.10    82    11  839.0  840.2  839.0
# 129   10.1  31394 -38.4 -75.4     1  0.14    50    16  872.3  874.0  872.4
# 130   10.0  31470 -38.3 -75.3     1  0.14    60    17  875.4  877.2  875.5
#
# [131 rows x 11 columns]

# %%
df = pd.DataFrame(df0)

# %%
df.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT      int64
# SKNT      int64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
x = df0.PRES
y = df0.HGHT

plt.figure()
plt.plot(x, y)
 
plt.xlabel('TEMPERATURA')
plt.ylabel('ALTURA')
 
plt.title('Temperatura como funcion de la altura')

plt.grid(True)
 
plt.show()

# %%
x = df0.TEMP
y = df0.HGHT

plt.figure()
plt.plot(x, y)

plt.xticks([1000,10000,100000], ['1k','10k','100k'])
    
plt.xlabel('TEMPERATURA')
plt.ylabel('ALTURA')
 
plt.title('Temperatura como funcion de la altura')

plt.grid(True)
 
plt.show()

# %%
x = df0.PRES
y = df0.HGHT

plt.figure()
plt.plot(x, y)
 
plt.xlabel('TEMPERATURA')
plt.ylabel('ALTURA')
 
plt.title('Temperatura como funcion de la altura')

plt.grid(True)
 
plt.show()
